# %%
from IPython.display import clear_output

# %%
# !pip install ultralytics
clear_output()

# %%
from ultralytics import YOLO

# %%
model = YOLO('/kaggle/input/yolo-seg/yolov8s-seg.pt')

# %%
# Train the model
results = model.train(data='/kaggle/input/t-shirt-seg/data.yaml', epochs=100)
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
model = YOLO('/kaggle/input/yolo-seg/yolov8s-seg.pt')

# %%
predictor = YOLO('/kaggle/working/runs/segment/train/weights/best.pt')

# %%
predicted = predictor('/kaggle/input/t-shirt-seg/train/images/1000_jpg.rf.462cccd59b54d6f9a5de1ae15a1634a0.jpg',save=True)
# Out:
# image 1/1 /kaggle/input/t-shirt-seg/train/images/1000_jpg.rf.462cccd59b54d6f9a5de1ae15a1634a0.jpg: 640x640 1 left_sleeve, 1 neck, 1 right_sleeve, 1 seam, 1 t_shirt, 10.5ms
# Speed: 1.6ms preprocess, 10.5ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict2

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/kaggle/working/runs/segment/predict2/1000_jpg.rf.462cccd59b54d6f9a5de1ae15a1634a0.jpg')

# %%
plt.imshow(img)
